# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

from src.agents import deep_research_agent

result = deep_research_agent.invoke({"messages": [{"role": "user", "content": "What is langgraph?"}]})

# Print the agent's response
print(result["messages"][-1].content)
# Out:
# LangGraph is an open-source AI agent framework developed by LangChain that enables the creation, deployment, and management of complex generative AI agent workflows. Here's a comprehensive overview:
#
# ## Core Features and Concepts
#
# **Graph-Based Architecture**: LangGraph uses graph-based architectures to model and manage relationships between components in AI agent workflows. This approach treats workflows as interconnected nodes and edges, providing a scalable and transparent way to design advanced AI systems.
#
# **State Management**: It's designed for building stateful, long-running applications that can maintain context and history throughout extended interactions.
#
# **Multi-Agent Coordination**: The framework excels at coordinating multiple LLM (Large Language Model) agents or chains in a structured manner, allowing developers to focus on high-level application logic rather than agent coordination details.
#
# ## Key Components
#
# **Nodes**: Represent individual components or agents within the workflow. These can be different AI agents, processing steps, or decision points.
#
# **Edges**: Define the connections and data flow between nodes, determining the sequence of operations.
#
# **Workflow Orchestration**: Manages the flow of data and execution sequence across the graph structure.
#
# ## Use Cases
#
# - Complex chatbots that handle various user request types
# - Multi-agent systems performing collaborative tasks
# - Stateful AI applications requiring memory of past interactions
# - Agent-based systems with sophisticated decision-making processes
#
# ## Development Environment
#
# LangGraph Studio provides a visual development environment that simplifies creating complex agentic applications built with LangChain components.
#
# ## Technical Positioning
#
# LangGraph serves as a low-level orchestration framework and runtime focused on core agent capabilities like:
# - Durable execution
# - Streaming
# - Human-in-the-loop functionality
# - Long-running, stateful workflows
#
# It integrates seamlessly with other LangChain products and can be used standalone, offering both local prototyping and production deployment options with observability features.
#
# The framework is trusted by companies like Klarna, Replit, and Elastic for building advanced AI agent systems.
